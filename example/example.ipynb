# %%
from trendpy import filter
from pandas import read_csv

from matplotlib import pyplot

# %%
filename='data.csv'
data = read_csv(filename)
y = data['time series']

# %%
pyplot.plot(data['time series'].values, markerfacecolor='blue', markersize=12, color='skyblue', linewidth=1)
pyplot.show()

# %%
x = filter(y,verbose=0)
# Out:
# /usr/local/lib/python3.7/site-packages/trendpy/samplers.py:344: RuntimeWarning: divide by zero encountered in double_scalars
#   return array([1/distribution.rvs(parameters['pos'][i],loc=parameters['loc'],scale=parameters['scale']) for i in range(len(self.parameters.list['omega'].current_value))]).reshape(self.parameters.list['omega'].current_value.shape)
# /usr/local/lib/python3.7/site-packages/scipy/stats/_multivariate.py:660: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)

# %%
pyplot.plot(data['time series'].values, markerfacecolor='blue', markersize=12, color='skyblue', linewidth=1)
pyplot.plot(x, color='olive', linewidth=1)
pyplot.show()
